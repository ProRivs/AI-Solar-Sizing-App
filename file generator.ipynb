# %%
import json

# Solar irradiance data for three locations in Cameroon (kWh/m²/day)
solar_irradiance = {
    "Yaounde": {
        "avg_irradiance": 5.2,
        "min_irradiance": 4.8,
        "max_irradiance": 5.6
    },
    "Douala": {
        "avg_irradiance": 4.9,
        "min_irradiance": 4.5,
        "max_irradiance": 5.3
    },
    "Garoua": {
        "avg_irradiance": 5.8,
        "min_irradiance": 5.4,
        "max_irradiance": 6.2
    }
}

# Save to JSON file
with open("solar_irradiance.json", "w") as f:
    json.dump(solar_irradiance, f, indent=2)

# Appliance power consumption data (Watts)
appliances = {
    "LED Bulb": {"power": 10, "typical_hours": 5},
    "Ceiling Fan": {"power": 75, "typical_hours": 8},
    "Refrigerator": {"power": 150, "typical_hours": 24},
    "Television": {"power": 100, "typical_hours": 4},
    "Laptop": {"power": 50, "typical_hours": 6}
}

# Save to JSON file
with open("appliances.json", "w") as f:
    json.dump(appliances, f, indent=2)

# %% [markdown]
# # solar data generation

# %%
import json

# Solar irradiance data for three locations in Cameroon (kWh/m²/day)
solar_irradiance = {
    "Yaounde": {
        "avg_irradiance": 5.2,
        "min_irradiance": 4.8,
        "max_irradiance": 5.6
    },
    "Douala": {
        "avg_irradiance": 4.9,
        "min_irradiance": 4.5,
        "max_irradiance": 5.3
    },
    "Garoua": {
        "avg_irradiance": 5.8,
        "min_irradiance": 5.4,
        "max_irradiance": 6.2
    }
}

# Appliance power consumption data (Watts)
appliances = {
    "LED Bulb": {"power": 10, "typical_hours": 5},
    "Ceiling Fan": {"power": 75, "typical_hours": 8},
    "Refrigerator": {"power": 150, "typical_hours": 24},
    "Television": {"power": 100, "typical_hours": 4},
    "Laptop": {"power": 50, "typical_hours": 6}
}

# Components database
components = {
    "batteries": [
        {
            "id": "li-ion",
            "name": "Lithium-Ion (LiFePO4) Battery",
            "tagline": "Long Lifespan & High Efficiency",
            "description": "Lithium batteries are lightweight, efficient, and durable, with deep discharge capabilities.",
            "best_for": "Residential homes and businesses prioritizing long-term value.",
            "lifespan": "10 - 15 years or 4000+ charge cycles",
            "price_per_kwh_xaf": {"min": 250000, "max": 450000, "avg": 350000},
            "pros": ["Long life", "High efficiency", "No maintenance", "Lightweight"],
            "cons": ["Higher initial cost"]
        },
        {
            "id": "tubular",
            "name": "Tubular Lead-Acid Battery",
            "tagline": "Reliable & Cost-Effective",
            "description": "Tubular batteries are robust and suited for regular cycling, but require maintenance.",
            "best_for": "Budget-conscious users and off-grid systems.",
            "lifespan": "4 - 6 years or 1500 charge cycles",
            "price_per_kwh_xaf": {"min": 100000, "max": 160000, "avg": 130000},
            "pros": ["Lower initial cost", "Widely available", "Robust technology"],
            "cons": ["Shorter lifespan", "Requires maintenance", "Heavy"]
        }
    ],
    "solarPanels": [
        {
            "id": "mono",
            "name": "Monocrystalline Solar Panel",
            "tagline": "High Efficiency & Sleek Design",
            "description": "Monocrystalline panels offer high efficiency due to their single-crystal structure.",
            "best_for": "Space-constrained installations.",
            "lifespan": "25 - 30 years",
            "price_per_watt_xaf": {"min": 500, "max": 800, "avg": 650},
            "pros": ["High efficiency", "Long lifespan", "Aesthetic appeal"],
            "cons": ["Higher cost"]
        },
        {
            "id": "poly",
            "name": "Polycrystalline Solar Panel",
            "tagline": "Cost-Effective & Reliable",
            "description": "Polycrystalline panels balance cost and performance with multiple crystal structures.",
            "best_for": "Budget-conscious users with sufficient space.",
            "lifespan": "20 - 25 years",
            "price_per_watt_xaf": {"min": 400, "max": 600, "avg": 500},
            "pros": ["Lower cost", "Good performance"],
            "cons": ["Lower efficiency"]
        }
    ],
    "inverters": [
        {
            "id": "string",
            "name": "String Inverter",
            "tagline": "Cost-Effective & Simple",
            "description": "String inverters convert DC to AC power for home use, ideal for unshaded roofs.",
            "best_for": "Standard residential systems.",
            "lifespan": "8 - 12 years",
            "price_per_kw_xaf": {"min": 200000, "max": 350000, "avg": 275000},
            "pros": ["Lower cost", "Simple installation"],
            "cons": ["Shading sensitivity"]
        }
    ],
    "chargeControllers": [
        {
            "id": "mppt",
            "name": "MPPT Charge Controller",
            "tagline": "Maximum Efficiency",
            "description": "MPPT controllers optimize power output from solar panels.",
            "best_for": "All solar systems.",
            "lifespan": "10 - 15 years",
            "price_per_unit_xaf": {"min": 100000, "max": 200000, "avg": 150000},
            "pros": ["High efficiency", "Flexible"],
            "cons": ["Higher cost"]
        }
    ],
    "installation": {
        "id": "install",
        "name": "Mounting & Installation",
        "tagline": "Professional Setup",
        "description": "Includes mounting hardware, wiring, and professional installation.",
        "best_for": "All solar systems.",
        "lifespan": "N/A",
        "price_per_system_xaf": {"min": 500000, "max": 1000000, "avg": 750000},
        "pros": ["Professional quality", "Ensures safety"],
        "cons": ["Significant upfront cost"]
    }
}

# Save datasets to JSON files
with open("solar_irradiance.json", "w") as f:
    json.dump(solar_irradiance, f, indent=2)

with open("appliances.json", "w") as f:
    json.dump(appliances, f, indent=2)

with open("components.json", "w") as f:
    json.dump(components, f, indent=2)

print("Datasets generated: solar_irradiance.json, appliances.json, components.json")
# Out:
# Datasets generated: solar_irradiance.json, appliances.json, components.json

# %% [markdown]
# # generate the training data

# %%
import pandas as pd
import numpy as np

# Simulate training data for each component category
categories = ["batteries", "solarPanels", "inverters", "chargeControllers"]
components = {
    "batteries": ["li-ion", "tubular"],
    "solarPanels": ["mono", "poly"],
    "inverters": ["string", "micro"],
    "chargeControllers": ["pwm", "mppt"]
}

# Generate synthetic data
np.random.seed(42)
n_samples = 1000

for category in categories:
    data = {
        "daily_energy_kwh": np.random.uniform(1, 20, n_samples),  # Daily energy demand in kWh
        "budget_million_xaf": np.random.uniform(0.1, 1.5, n_samples),  # Budget in million XAF
        "avg_cost": np.random.uniform(100_000, 500_000, n_samples),  # Average component cost in XAF
        "lifespan": np.random.choice([5, 10, 15, 20], n_samples),  # Component lifespan in years
        "install_type": np.random.choice([0, 1], n_samples),  # 0: rural, 1: urban
        "label": np.random.choice(components[category], n_samples)  # Component ID
    }
    
    # Adjust labels based on heuristic rules
    df = pd.DataFrame(data)
    for i in range(n_samples):
        energy = df.loc[i, "daily_energy_kwh"]
        budget = df.loc[i, "budget_million_xaf"]
        if category == "batteries":
            df.loc[i, "label"] = "li-ion" if energy > 10 and budget > 0.5 else "tubular"
        elif category == "solarPanels":
            df.loc[i, "label"] = "mono" if energy > 8 and budget > 0.7 else "poly"
        elif category == "inverters":
            df.loc[i, "label"] = "micro" if energy > 12 and budget > 0.8 else "string"
        elif category == "chargeControllers":
            df.loc[i, "label"] = "mppt" if energy > 5 and budget > 0.4 else "pwm"
    
    # Save to CSV
    df.to_csv(f"{category}_training_data.csv", index=False)

print("Training data generated: batteries_training_data.csv, solarPanels_training_data.csv, inverters_training_data.csv, chargeControllers_training_data.csv")
# Out:
# Training data generated: batteries_training_data.csv, solarPanels_training_data.csv, inverters_training_data.csv, chargeControllers_training_data.csv

# %% [markdown]
# # Fetch_irradiance_data.py
# Fetches and preprocesses NASA POWER irradiance data for training the Prophet model.
# ## Details:
#
# - Fetches daily irradiance data (2020–2024) from NASA POWER API for Yaounde, Douala, and Garoua.
# - Saves data as CSV files ({city}_irradiance_data.csv) for Prophet training.
# - Handles missing data by skipping invalid entries.

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# NASA POWER API endpoint
base_url = "https://power.larc.nasa.gov/api/temporal/daily/point"

# Coordinates for Yaounde, Douala, Garoua
locations = {
    "Yaounde": {"lat": 3.848, "lon": 11.502},
    "Douala": {"lat": 4.051, "lon": 9.704},
    "Garoua": {"lat": 9.301, "lon": 13.398}
}

# Parameters
parameters = "ALLSKY_SFC_SW_DWN"  # Surface solar irradiance (kWh/m²/day)
start_date = "20200101"
end_date = "20241231"

# Fetch data
data = {}
for city, coords in locations.items():
    url = f"{base_url}?parameters={parameters}&community=RE&longitude={coords['lon']}&latitude={coords['lat']}&start={start_date}&end={end_date}&format=JSON"
    response = requests.get(url)
    if response.status_code == 200:
        json_data = response.json()
        # Extract daily irradiance
        dates = []
        irradiance = []
        for date, value in json_data["properties"]["parameter"]["ALLSKY_SFC_SW_DWN"].items():
            if value != -999:  # Skip missing data
                dates.append(datetime.strptime(date, "%Y%m%d"))
                irradiance.append(value)
        data[city] = pd.DataFrame({"ds": dates, "y": irradiance})
    else:
        print(f"Failed to fetch data for {city}")

# Save data for Prophet training
for city, df in data.items():
    df.to_csv(f"{city}_irradiance_data.csv", index=False)

print("Irradiance data saved: Yaounde_irradiance_data.csv, Douala_irradiance_data.csv, Garoua_irradiance_data.csv")
# Out:
# Irradiance data saved: Yaounde_irradiance_data.csv, Douala_irradiance_data.csv, Garoua_irradiance_data.csv
